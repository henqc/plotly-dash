# %% [markdown]
# # IMDB Top 1000 Movies

# %% [markdown]
# ### Why the Data was Chosen

# %% [markdown]
# The data was chosen to build an intuitive yet informative interactive app based around movie data. The data set features interesting variables that would provide a rich and meaningful analysis for my film student persona. Understanding cinema goes beyond viewership; it requires an analytical lens to appreciate its complexity fully. This data set will help provide insight into trends in overall gross and ratings when taking into account a films actors, directors, and release dates. This will help the film student draw conclusions about why some films are more successful than others.

# %% [markdown]
# ### Data Provenance

# %% [markdown]
# The data set was taken from Kaggle (https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows). The author of this data set has indicated that this data was scraped from the IMDB site (https://www.imdb.com/) for the purpose of easy analysis for the public. I will be using this data to look for trends and commonailities in the top IMDB movies. This dataset has License CC0 meaning the author has relinquished all copyright and similar rights on the work and dedicated those rights to the public domain.

# %% [markdown]
# ### Data Cleaning

# %%
# Import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load in Data and view first couple rows
df = pd.read_csv("./imdb_top_1000.csv")
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A  142 min
# 1             The Godfather           1972           A  175 min
# 2           The Dark Knight           2008          UA  152 min
# 3    The Godfather: Part II           1974           A  202 min
# 4              12 Angry Men           1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
# Drop poster link and overvierw col and view information on the columns of the dataframe
df.drop(['Poster_Link', 'Overview'], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   int64
#  2   Certificate    899 non-null    object
#  3   Runtime        1000 non-null   object
#  4   Genre          1000 non-null   object
#  5   IMDB_Rating    1000 non-null   float64
#  6   Meta_score     843 non-null    float64
#  7   Director       1000 non-null   object
#  8   Star1          1000 non-null   object
#  9   Star2          1000 non-null   object
#  10  Star3          1000 non-null   object
#  11  Star4          1000 non-null   object
#  12  No_of_Votes    1000 non-null   int64
#  13  Gross          831 non-null    object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 109.5+ KB

# %%
# Dealing with Missing Values in Certificate, Meta_score, and Gross
df = df.dropna(subset=['Certificate', 'Gross', 'Meta_score'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 997
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   714 non-null    object
#  1   Released_Year  714 non-null    int64
#  2   Certificate    714 non-null    object
#  3   Runtime        714 non-null    object
#  4   Genre          714 non-null    object
#  5   IMDB_Rating    714 non-null    float64
#  6   Meta_score     714 non-null    float64
#  7   Director       714 non-null    object
#  8   Star1          714 non-null    object
#  9   Star2          714 non-null    object
#  10  Star3          714 non-null    object
#  11  Star4          714 non-null    object
#  12  No_of_Votes    714 non-null    int64
#  13  Gross          714 non-null    object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 83.7+ KB

# %%
# Convert Released_Year to numerical data
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')

# Extract the numerical component of Runtime as numerical data
df['Runtime'] = df['Runtime'].str.extract('(\\d+)').astype(float)

# Remove commas from Gross and convert to numerical data
df['Gross'] = df['Gross'].str.replace(',', '').astype(float)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 997
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   714 non-null    object
#  1   Released_Year  714 non-null    int64
#  2   Certificate    714 non-null    object
#  3   Runtime        714 non-null    float64
#  4   Genre          714 non-null    object
#  5   IMDB_Rating    714 non-null    float64
#  6   Meta_score     714 non-null    float64
#  7   Director       714 non-null    object
#  8   Star1          714 non-null    object
#  9   Star2          714 non-null    object
#  10  Star3          714 non-null    object
#  11  Star4          714 non-null    object
#  12  No_of_Votes    714 non-null    int64
#  13  Gross          714 non-null    float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 83.7+ KB

# %%
# Split Genre col by comma seperators and create a new dummy for each genre
genre_dummies = df['Genre'].str.get_dummies(sep=', ')

# Concatenating the original dataFrame with the new dummies dataFrame. Now we had a col for every genre where a 1 indicates it is that genre
final_df = pd.concat([df.drop('Genre', axis=1), genre_dummies], axis=1)

final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 997
# Data columns (total 34 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   714 non-null    object
#  1   Released_Year  714 non-null    int64
#  2   Certificate    714 non-null    object
#  3   Runtime        714 non-null    float64
#  4   IMDB_Rating    714 non-null    float64
#  5   Meta_score     714 non-null    float64
#  6   Director       714 non-null    object
#  7   Star1          714 non-null    object
#  8   Star2          714 non-null    object
#  9   Star3          714 non-null    object
#  10  Star4          714 non-null    object
#  11  No_of_Votes    714 non-null    int64
#  12  Gross          714 non-null    float64
#  13  Action         714 non-null    int64
#  14  Adventure      714 non-null    int64
#  15  Animation      714 non-null    int64
#  16  Biography      714 non-null    int64
#  17  Comedy         714 non-null    int64
#  18  Crime          714 non-null    int64
#  19  Drama          714 non-null    int64
#  20  Family         714 non-null    int64
#  21  Fantasy        714 non-null    int64
#  22  Film-Noir      714 non-null    int64
#  23  History        714 non-null    int64
#  24  Horror         714 non-null    int64
#  25  Music          714 non-null    int64
#  26  Musical        714 non-null    int64
#  27  Mystery        714 non-null    int64
#  28  Romance        714 non-null    int64
#  29  Sci-Fi         714 non-null    int64
#  30  Sport          714 non-null    int64
#  31  Thriller       714 non-null    int64
#  32  War            714 non-null    int64
#  33  Western        714 non-null    int64
# dtypes: float64(4), int64(23), object(7)
# memory usage: 195.2+ KB

# %%
# Export to data.csv
final_df.to_csv('data.csv', index=False)

# %% [markdown]
# ### Exploratory Analysis

# %% [markdown]
# #### Amount of Observations

# %%
final_df.shape
# Out:
# (714, 34)

# %% [markdown]
# There are 714 total observations each with 34 variables

# %% [markdown]
# #### Amount of categories for categorical variables

# %%
# Get the amount of unique genres
unique_genres = set(df['Genre'].str.split(', ').explode().unique())
print(unique_genres)
print(f"Number of unique genres: {len(unique_genres)}")
# Out:
# {'Comedy', 'War', 'Western', 'Music', 'History', 'Action', 'Biography', 'Horror', 'Fantasy', 'Animation', 'Sci-Fi', 'Film-Noir', 'Musical', 'Crime', 'Family', 'Mystery', 'Thriller', 'Drama', 'Romance', 'Adventure', 'Sport'}
# Number of unique genres: 21

# %% [markdown]
# In the original dataframe, Genre was a catagorical varible that could contain any combination of the 21 unique genres. In data.csv the genres are split into different cols to maintain the tidy data format

# %%
# Get the amount of unique stars
all_stars = pd.concat([final_df['Star1'], final_df['Star2'], final_df['Star3'], final_df['Star4']]).unique()
unique_stars = set(all_stars)
print(unique_stars)
print(f"Number of unique stars: {len(unique_stars)}")
# Out:
# {'Babak Karimi', 'Anthony Michael Hall', 'Tony Moran', 'Caroline Goodall', 'Saif Ali Khan', 'Pamela Adlon', 'Sandra Bullock', 'Ben Johnson', 'Jeff Garlin', 'Dan Hicks', 'Joanna Cassidy', 'Lee Pace', 'Eddie Murphy', 'Anne Le Ny', 'Holly Hunter', 'Izabela Vidovic', 'Lee Sun-kyun', 'Anna Kendrick', 'Katrin Cartlidge', 'Thomas Bo Larsen', 'Pernilla Allwin', 'Alan Ruck', 'Barry Bostwick', 'Emmy Rossum', 'Roy Dotrice', 'Gastone Moschin', 'Olivia Cooke', 'Ellen Burstyn', 'Jan Sterling', "Paige O'Hara", 'Katrin Saß', 'Niels Arestrup', 'Matvey Novikov', 'Rory Cochrane', 'Sally Hawkins', 'Jane Galloway Heitz', 'Donald Sutherland', 'Jim Carrey', 'Stephen Boyd', 'Samuel L. Jackson', 'Anne-Marie Duff', 'Gérard Jugnot', 'Andrew Garfield', 'Meat Loaf', 'Brian Cox', 'Graham Greene', 'Julia Ormond', 'Ariane Labed', 'Donny Alamsyah', 'Patrick McGoohan', "Auli'i Cravalho", 'Greg Kinnear', 'Suzanne Pleshette', 'Natalie Dessay', 'Philip Seymour Hoffman', 'Jay Baruchel', 'Emma Thompson', 'Dexter Fletcher', 'Bae Doona', 'Chris Cooper', 'Mary Kay Bergman', 'Mila Kunis', 'Joséphine Lebas-Joly', 'Leonor Watling', 'Taraji P. Henson', 'Jason London', 'Claudette Colbert', 'Jessica Tandy', 'Shin Ha-kyun', 'Yûko Tanaka', 'Armie Hammer', 'Sarah Jessica Parker', 'Eric Schweig', 'Ben Affleck', 'Charles Martin Smith', 'Fay Wray', 'James Stewart', 'J.T. Walsh', 'Jane Alexander', 'Martin Freeman', 'Janelle Monáe', 'Mikkel Boe Følsgaard', 'Adil Hussain', 'Melinda Dillon', 'Gary Oldman', 'Kim Byeong-Ok', 'Stanley Holloway', 'Ezra Miller', 'Yeong-su Oh', 'Akihiro Miwa', 'Frank Finlay', 'Stanislas Carré de Malberg', 'Sean Astin', 'Shailene Woodley', 'Brenda Blethyn', 'Anne Hathaway', 'Paul McGann', 'Geraldine Chaplin', 'Paul Bettany', 'Paul Winfield', 'Bradley Whitford', 'Adel Bencherif', 'Farley Granger', 'Kaitlyn Dever', 'Burt Lancaster', 'Katharine Ross', 'Maurice Evans', 'Mark Ruffalo', 'Roddy McDowall', 'Moon So-Ri', 'Diane Ladd', 'Mabel Rivera', 'Tony Curtis', 'Ian Holm', 'Mercedes Morán', 'Ryan Hurst', 'Chris Elliott', 'Lisanne Falk', 'Ken Leung', 'Bill Sage', 'Kassie Wesley DePaiva', 'Michael Peña', 'Paul McCartney', 'Mohammad Amir Naji', 'Terry Jones', 'Teri Hatcher', 'Jesse Borrego', 'Robert Morley', 'Geoffrey Rush', 'Giorgio Cantarini', 'Jae Head', 'Don Hall', 'Stephen Trask', 'Jack McBrayer', 'Henry Thomas', 'Sylvia Hoeks', 'Richard Dreyfuss', 'Julia Jones', 'J.D. Cannon', 'Lina Leandersson', 'Maggie Cheung', 'Lola Dueñas', 'Dave Goelz', 'Mone Kamishiraishi', 'Ruth Nelson', 'Halina Reijn', 'Shahab Hosseini', 'Darren McGavin', 'Branka Katic', 'Pete Postlethwaite', 'Melissa Leo', 'Teo Briones', 'Tom Prior', 'Eleanor Bron', 'Charles Chaplin', 'Daniel Craig', 'Ali Mosaffa', 'Benno Fürmann', 'James McAvoy', 'Peter Wyngarde', 'Steve Carell', 'Rachel Ticotin', 'Sarah Silverman', 'Yordanos Shiferaw', 'Don Rickles', 'Will Poulter', 'Dorothy Comingore', 'Gert Fröbe', 'Siu-Lung Leung', 'Jean-Marc Barr', 'Rosanna Arquette', 'Elpidia Carrillo', 'Atsuko Tanaka', 'Pascal Greggory', 'Reginald VelJohnson', 'Jack Kehoe', 'Russell Crowe', 'Margot Robbie', 'Owen Wilson', 'Tilda Swinton', 'David Hand', 'Cleavon Little', 'Jack Warden', 'Lyubov Agapova', 'Russell Means', 'George Kennedy', 'Lawrence A. Bonney', 'Bradley Cooper', 'Rachel Weisz', 'Nakul Roshan Sahdev', 'Josef Altin', 'Graciela Tenenbaum', 'Megumi Hayashibara', 'Haley Joel Osment', 'Patrick Stewart', 'Yoshiaki Umegaki', 'Candela Peña', 'Sophie Perry', 'Michael Redgrave', "Jerry O'Connell", 'John Heard', 'Felicity Jones', 'Jennifer Saunders', 'Dean Martin', 'Barkhad Abdirahman', 'Enzo Cannavale', 'Suraj Sharma', 'Fernanda Montenegro', 'Priscilla Presley', "Beverly D'Angelo", 'Cary Elwes', 'John Malkovich', 'Bruce Willis', 'John Huston', 'Jin-mo Joo', 'Aya Okamoto', 'John Cho', 'Malcolm McDowell', 'Paul Scofield', 'Walton Goggins', 'Gattlin Griffith', 'Jim Varney', 'Sharman Joshi', 'Jane Darwell', 'Orson Welles', 'Bahare Seddiqi', 'Jamie Chung', 'Ally Sheedy', 'Sakura Andô', 'John Williams', 'Josh Charles', 'Brigitte ...
# Number of unique stars: 1914

# %% [markdown]
# A movie has a combination of four stars from the 1914 unique stars.

# %%
# Get the amount of unique titles
unique_titles = final_df['Series_Title'].unique()
set(unique_titles)
print(unique_titles)
print(f"Number of unique titles: {len(unique_titles)}")
# Out:
# ['The Shawshank Redemption' 'The Godfather' 'The Dark Knight'
#  'The Godfather: Part II' '12 Angry Men'
#  'The Lord of the Rings: The Return of the King' 'Pulp Fiction'
#  "Schindler's List" 'Inception' 'Fight Club'
#  'The Lord of the Rings: The Fellowship of the Ring' 'Forrest Gump'
#  'Il buono, il brutto, il cattivo' 'The Lord of the Rings: The Two Towers'
#  'The Matrix' 'Goodfellas'
#  'Star Wars: Episode V - The Empire Strikes Back'
#  "One Flew Over the Cuckoo's Nest" 'Gisaengchung' 'Interstellar'
#  'Cidade de Deus' 'Sen to Chihiro no kamikakushi' 'Saving Private Ryan'
#  'The Green Mile' 'La vita è bella' 'Se7en' 'The Silence of the Lambs'
#  'Star Wars' 'Shichinin no samurai' 'Joker' 'Whiplash' 'The Intouchables'
#  'The Prestige' 'The Departed' 'The Pianist' 'Gladiator'
#  'American History X' 'The Usual Suspects' 'Léon' 'The Lion King'
#  'Terminator 2: Judgment Day' 'Nuovo Cinema Paradiso' 'Back to the Future'
#  'Once Upon a Time in the West' 'Psycho' 'Casablanca' 'Modern Times'
#  'City Lights' 'Capharnaüm' 'Kimi no na wa.'
#  'Spider-Man: Into the Spider-Verse' 'Avengers: Endgame'
#  'Avengers: Infinity War' 'Coco' 'Django Unchained'
#  'The Dark Knight Rises' '3 Idiots' 'WALL·E' 'The Lives of Others'
#  'Oldeuboi' 'Memento' 'Mononoke-hime' 'Raiders of the Lost Ark'
#  'The Shining' 'Apocalypse Now' 'Alien'
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb'
#  'Rear Window' '1917' 'Jagten' 'Jodaeiye Nader az Simin' 'Incendies'
#  'Inglourious Basterds' 'Eternal Sunshine of the Spotless Mind' 'Amélie'
#  'Snatch' 'Requiem for a Dream' 'American Beauty' 'Good Will Hunting'
#  'Bacheha-Ye aseman' 'Toy Story' 'Braveheart' 'Reservoir Dogs'
#  'Full Metal Jacket' 'Aliens' 'Amadeus' 'Scarface'
#  'Star Wars: Episode VI - Return of the Jedi' 'Das Boot' 'Taxi Driver'
#  'The Sting' 'A Clockwork Orange' '2001: A Space Odyssey'
#  'Per qualche dollaro in più' 'Lawrence of Arabia' 'The Apartment'
#  'North by Northwest' 'Vertigo' "Singin' in the Rain" 'Double Indemnity'
#  'Citizen Kane' 'Green Book' 'Three Billboards Outside Ebbing, Missouri'
#  'El secreto de sus ojos' 'Warrior' 'Shutter Island' 'Up'
#  'The Wolf of Wall Street' 'Chak De! India' 'There Will Be Blood'
#  "Pan's Labyrinth" 'Toy Story 3' 'V for Vendetta' 'Batman Begins'
#  'Der Untergang' 'Hauru no ugoku shiro' 'A Beautiful Mind'
#  'Lock, Stock and Two Smoking Barrels' 'L.A. Confidential' 'Heat' 'Casino'
#  'Unforgiven' 'Indiana Jones and the Last Crusade' 'Tonari no Totoro'
#  'Die Hard' 'Ran' 'Raging Bull' 'Monty Python and the Holy Grail'
#  'The Great Escape' 'Some Like It Hot' 'Dial M for Murder' 'All About Eve'
#  'The Treasure of the Sierra Madre' 'Portrait de la jeune fille en feu'
#  'Ah-ga-ssi' 'Mommy' 'Logan' 'Room' 'Relatos salvajes'
#  'The Grand Budapest Hotel' 'Gone Girl' 'Hacksaw Ridge' 'Inside Out'
#  '12 Years a Slave' 'Rush' 'Ford v Ferrari' 'Spotlight' 'Song of the Sea'
#  'Prisoners' 'Mad Max: Fury Road' 'Gran Torino'
#  'Harry Potter and the Deathly Hallows: Part 2' 'Okuribito'
#  'How to Train Your Dragon' 'Into the Wild' 'No Country for Old Men'
#  'Million Dollar Baby' 'Hotel Rwanda' 'Taegukgi hwinalrimyeo'
#  'Before Sunset' 'Salinui chueok' 'Kill Bill: Vol. 1' 'Finding Nemo'
#  'Catch Me If You Can' 'Amores perros' 'Monsters, Inc.'
#  'Lagaan: Once Upon a Time in India' 'The Sixth Sense'
#  "La leggenda del pianista sull'oceano" 'The Truman Show'
#  'Crna macka, beli macor' 'The Big Lebowski' 'Fa yeung nin wah'
#  'Trainspotting' 'Fargo' 'Before Sunrise' 'Trois couleurs: Rouge'
#  'Chung Hing sam lam' 'Jurassic Park' 'In the Name of the Father'
#  'Dead Poets Society' 'Stand by Me' 'Platoon' 'Paris, Texas'
#  'Kaze no tani no Naushika' 'The Thing' 'Pink Floyd: The Wall'
#  'Fanny och Alexander' 'Blade Runner' 'Life of Brian' 'The Deer Hunter'
#  'Rocky' 'Chinatown' 'Paper Moon' 'Cool Hand Luke'
#  'What Ever Happened to Baby Jane?' 'Ben-Hur'
#  'The Bridge on the River Kwai' 'On the Waterfront' 'Ace in the Hole'
#  'The Third Man' 'Rebecca' 'Mr. Smith Goes to Washington'
#  'Gone with the Wind' 'It Happened One Night' 'La La Land' 'Lion'
#  'The Martian' 'Zootopia' 'Kaguyahime no monogatari' 'Wonder' 'Gully Boy'
#  'Short Term 12' 'Serbuan maut 2: Berandal' 'The Imitation Game'
#  'Guardians of the Galaxy' 'Blade Runner 2049' 'Her' 'Bohemian Rhapsody'
#  'The Revenant' 'The Perks of Being a Wallflower' "The King's Speech"
#  'The Help' 'Deadpool' 'Darbareye Elly' 'My Name Is Khan'
#  'Slumdog Millionaire' 'Black Swan' 'Tropa de Elite' 'The Avengers'
#  'Persepolis' 'Dallas Buyers Club' 'The Pursuit of Happyness'
#  'Blood Diamond' 'The Bourne Ultimatum' 'Bin-jip' 'Sin City'
#  'Le scaphandre et le papillon' 'Ratatouille' 'Casino Royale'
#  'Kill Bill: Vol. 2' 'Bom Yeoareum Gaeul Gyeoul Geurigo Bom' 'Mar adentro'
#  'Cinderella Man' 'Kal Ho Naa Ho' 'Mou gaan dou'
#  'Pirates of the Caribbean: The Curse of the Black Pearl' 'Big Fish'
#  'The Incredibles' 'Dogville' 'Donnie Darko' 'Magnolia'
#  'Dancer in the Dark' 'The Straight Story' 'Festen' 'Central do Brasil'
#  'The Iron Giant' 'Sling Blade' 'Secrets & Lies' 'Twelve Monkeys'
#  'Kôkaku Kidôtai' 'The Nightmare Before Christmas' 'Groundhog Day'
#  'Bound by Honor' 'Scent of a Woman' 'Aladdin' 'JFK'
#  'Beauty and the Beast' 'Dances with Wolves' 'Do the Right Thing'
#  'Rain Man' 'The Princess Bride' 'Der Himmel über Berlin'
#  'Au revoir les enfants' 'The Terminator' 'Gandhi' 'Being There'
#  'Annie Hall' 'Jaws' 'Dog Day Afternoon' 'Young Frankenstein' 'Papillon'
#  'The Exorcist' 'The Last Picture Show' 'Fiddler on the Roof'
#  'Il conformista' 'Butch Cassidy and the Sundance Kid'
#  'Planet of the Apes' 'The Graduate' 'The Sound of Music' 'Doctor Zhivago'
#  'Per un pugno di dollari' 'The Hustler' 'La dolce vita' 'Rio Bravo'
#  'Touch of Evil' 'Cat on a Hot Tin Roof' 'A Streetcar Named Desire'
#  'The Best Years of Our Lives' 'The Grapes of Wrath' 'The Wizard of Oz'
#  'All Quiet on the Western Front' 'Knives Out' 'Manbiki kazoku'
#  'Marriage Story' 'Call Me by Your Name' 'I, Daniel Blake' 'Isle of Dogs'
#  'Hunt for the Wilderpeople' 'Captain Fantastic' 'Sing Street'
#  'Thor: Ragnarok' 'Nightcrawler' 'Jojo Rabbit' 'Arrival'
#  'Star Wars: Episode VII - The Force Awakens' 'Before Midnight'
#  'X-Men: Days of Future Past' 'The Artist' 'Edge of Tomorrow' 'Amour'
#  'The Irishman' 'Un prophète' 'Moon' 'Låt den rätte komma in' 'District 9'
#  'The Wrestler' 'Boyhood' 'Star Trek' 'In Bruges' 'Letters from Iwo Jima'
#  'The Fall' 'Life of Pi' 'Fantastic Mr. Fox' 'Les choristes' 'Iron Man'
#  'Shaun of the Dead' 'Mystic River'
#  'Harry Potter and the Prisoner of Azkaban' 'Ying xiong' 'Hable con ella'
#  "No Man's Land" 'Cowboy Bebop: Tengoku no tobira' 'The Bourne Identity'
#  'Nueve reinas' 'Children of Men' 'Almost Famous' 'Mulholland Dr.'
#  'Toy Story 2' 'Boogie Nights' 'Once Were Warriors' 'True Romance'
#  'Trois couleurs: Bleu' "Carlito's Way" 'Edward Scissorhands'
#  'My Left Foot: The Story of Christy Brown' 'Crimes and Misdemeanors'
#  'The Untouchables' 'Hannah and Her Sisters' 'Brazil' 'This Is Spinal Tap'
#  'A Christmas Story' 'The Blues Brothers' 'Manhattan' 'All That Jazz'
#  'Dawn of the Dead' "All the President's Men" 'La montaña sagrada'
#  'Le charme discret de la bourgeoisie' 'Patton' 'The Wild Bunch'
#  'In the Heat of the Night' 'Charade' 'Spartacus' 'High Noon'
#  'Strangers on a Train' 'Notorious' 'The Adventures of Robin Hood'
#  'King Kong' 'Forushande' 'Dunkirk' 'Hidden Figures' 'Paddington 2'
#  'Kubo and the Two Strings' 'Manchester by the Sea' 'Under sandet'
#  'Rogue One' 'Captain America: Civil War' 'The Hateful Eight'
#  'Little Women' 'Loving Vincent' 'Le passé' 'The Lunchbox' 'Big Hero 6'
#  'About Time' 'Kaze tachinu' 'Toy Story 4' 'La migliore offerta'
#  'Moonrise Kingdom' 'How to Train Your Dragon 2' 'The Big Short'
#  'The Girl with the Dragon Tattoo' 'Captain Phillips'
#  'Straight Outta Compton' 'Madeo' 'The Hobbit: The Desolation of Smaug'
#  'Das weiße Band - Eine deutsche Kindergeschichte' 'Män som hatar kvinnor'
#  'The Fighter' 'Taken' 'The Boy in the Striped Pyjamas' 'Once'
#  'The Hobbit: An Unexpected Journey' 'Atonement' 'Drive'
#  'American Gangster' 'Avatar' 'Mr. Nobody' 'Apocalypto'
#  'Little Miss Sunshine' 'Hot Fuzz' 'The Curious Case of Benjamin Button'
#  'Veer-Zaara' 'Adams æbler' 'Pride & Prejudice'
#  "The World's Fastest Indian" 'Tôkyô goddofâzâzu' 'Serenity'
#  'Walk the Line' 'The Notebook' 'Diarios de motocicleta' 'Lilja 4-ever'
#  'Les triplettes de Belleville' 'The Count of Monte Cristo' 'Waking Life'
#  'Remember the Titans' 'Wo hu cang long' 'Todo sobre mi madre' 'Cast Away'
#  'The Boondock Saints' 'The Insider' 'October Sky' 'Shrek' 'Titanic'
#  'Gattaca' 'The Game' 'Breaking the Waves' 'Ed Wood'
#  "What's Eating Gilbert Grape" 'Tombstone' 'The Sandlot'
#  'The Remains of the Day' 'The Fugitive' 'A Bronx Tale' 'Night on Earth'
#  'La double vie de Véronique' 'Boyz n the Hood' 'Misery' 'Awakenings'
#  'Glory' 'Back to the Future Part II' 'Mississippi Burning' 'Predator'
#  'Evil Dead II' "Ferris Bueller's Day Off" 'Down by Law' 'The Goonies'
#  'The Color Purple' 'The Breakfast Club' 'The Killing Fields'
#  'Ghostbusters' 'The Right Stuff' 'The King of Comedy'
#  'E.T. the Extra-Terrestrial' 'Kramer vs. Kramer' 'The Outlaw Josey Wales'
#  'The Conversation' 'La planète sauvage' 'The Day of the Jackal' 'Cabaret'
#  'Willy Wonka & the Chocolate Factory' 'Midnight Cowboy' 'My Fair Lady'
#  'Mary Poppins' 'The Longest Day' 'The Innocents' 'Deadpool 2'
#  'Wind River' 'Get Out' 'Mission: Impossible - Fallout'
#  'En man som heter Ove' 'What We Do in the Shadows' 'Omoide no Mânî'
#  'The Theory of Everything' 'Kingsman: The Secret Service'
#  'The Fault in Our Stars' 'Me and Earl and the Dying Girl'
#  'Birdman or (The Unexpected Virtue of Ignorance)' "La vie d'Adèle"
#  'Kai po che!' 'Captain America: The Winter Soldier' 'Nebraska'
#  'Wreck-It Ralph' 'Le Petit Prince' 'Midnight in Paris' 'The Lego Movie'
#  'Gravity' 'Star Trek Into Darkness' 'The Social Network' 'X: First Class'
#  'The Hangover' 'Skyfall' 'Silver Linings Playbook' 'Argo'
#  '(500) Days of Summer' 'Harry Potter and the Deathly Hallows: Part 1'
#  'Gake no ue no Ponyo' 'Frost/Nixon' 'Papurika' 'Changeling' 'Flipped'
#  'Ex Machina' 'Efter brylluppet' 'The Last King of Scotland' 'Zodiac'
#  'Lucky Number Slevin' 'Joyeux Noël' 'Control' 'Tangled' 'Zwartboek'
#  'Brokeback Mountain' '3:10 to Yuma' 'Crash' 'Kung fu'
#  'The Bourne Supremacy' 'The Machinist' 'Ray' 'Lost in Translation'
#  'Harry Potter and the Goblet of Fire' 'Man on Fire' 'Coraline'
#  'The Last Samurai' 'The Magdalene Sisters' 'Good Bye Lenin!' 'In America'
#  'I Am Sam' 'Adaptation.' 'Black Hawk Down' 'Road to Perdition'
#  'Das Experiment' 'Billy Elliot' 'Hedwig and the Angry Inch'
#  "Ocean's Eleven" 'Vampire Hunter D: Bloodlust'
#  'O Brother, Where Art Thou?' 'South Park: Bigger, Longer & Uncut'
#  'Office Space' 'Training Day' 'Rushmore' 'Being John Malkovich'
#  'As Good as It Gets' 'The Fifth Element' 'Le dîner de cons'
#  'Donnie Brasco' 'Shine' 'Primal Fear' 'A Little Princess' 'Il postino'
#  'Clerks' 'Short Cuts' 'Philadelphia' 'The Muppet Christmas Carol'
#  'Malcolm X' 'The Last of the Mohicans' 'Glengarry Glen Ross'
#  'A Few Good Men' 'Fried Green Tomatoes' 'Barton Fink' "Miller's Crossing"
#  'Who Framed Roger Rabbit' 'Withnail & I' 'The Last Emperor'
#  'Empire of the Sun' 'Der Name der Rose' 'Blue Velvet'
#  'The Purple Rose of Cairo' 'After Hours' 'The Verdict'
#  'Star Trek II: The Wrath of Khan' 'First Blood' 'Ordinary People'
#  'Airplane!' 'Halloween' 'Le locataire' 'Blazing Saddles' 'Serpico'
#  'Enter the Dragon' 'Deliverance' 'The French Connection' 'Dirty Harry'
#  'The Odd Couple' 'A Man for All Seasons' 'Goldfinger' 'The Birds'
#  'The Magnificent Seven' 'The African Queen' 'Fantasia' 'Searching'
#  'Once Upon a Time... in Hollywood' 'Nelyubov' 'The Florida Project'
#  'Gifted' 'The Peanut Butter Falcon' 'Mustang'
#  'Guardians of the Galaxy Vol. 2' 'Baby Driver' 'Only the Brave'
#  'Bridge of Spies' 'Incredibles 2' 'Moana' 'Sicario' 'Creed' 'Leviafan'
#  'Hell or High Water' 'Philomena' 'Dawn of the Planet of the Apes'
#  'Serbuan maut' 'End of Watch' 'Kari-gurashi no Arietti' 'A Star Is Born'
#  'True Grit' 'Hævnen' 'Despicable Me' '50/50' 'Kick-Ass' 'Moneyball'
#  'La piel que habito' 'Zombieland' 'Sherlock Holmes' 'The Blind Side'
#  'The Visitor' 'Seven Pounds' 'Eastern Promises' 'Stardust' 'Inside Man'
#  'Gone Baby Gone' 'La Vie En Rose' 'Huo Yuan Jia' 'The Illusionist'
#  'Harry Potter and the Half-Blood Prince' '300' 'Match Point' 'Watchmen'
#  'Lord of War' 'Saw' 'Synecdoche, New York' 'Mysterious Skin'
#  "Jeux d'enfants" 'Un long dimanche de fiançailles' 'The Station Agent'
#  '21 Grams' 'Boksuneun naui geot' 'Finding Neverland' '25th Hour'
#  'The Butterfly Effect' '28 Days Later...' 'The Royal Tenenbaums'
#  'Y tu mamá también' "Harry Potter and the Sorcerer's Stone" 'The Others'
#  'Blow' 'Enemy at the Gates' 'Minority Report' 'The Hurricane'
#  'American Psycho' 'Lola rennt' 'The Thin Red Line' 'Mulan'
#  'Fear and Loathing in Las Vegas' 'Dark City' 'Sleepers' 'Lost Highway'
#  'Sense and Sensibility' 'Die Hard: With a Vengeance' 'Dead Man'
#  'The Bridges of Madison County' 'Apollo 13' 'Trois couleurs: Blanc'
#  'Falling Down' 'Dazed and Confused' 'My Cousin Vinny' 'Omohide poro poro'
#  'Delicatessen' 'Home Alone' 'The Godfather: Part III'
#  'When Harry Met Sally...' 'The Little Mermaid'
#  'The Naked Gun: From the Files of Police Squad!'
#  'Planes, Trains & Automobiles' 'Lethal Weapon' 'Blood Simple'
#  'On Golden Pond' 'Mad Max 2' 'The Warriors' 'The Muppet Movie'
#  'Escape from Alcatraz' 'Midnight Express'
#  'Close Encounters of the Third Kind' 'The Long Goodbye' 'Giù la testa'
#  "Kelly's Heroes" 'The Jungle Book' "A Hard Day's Night"
#  'From Here to Eternity']
# Number of unique titles: 714

# %% [markdown]
# There are 714 unique film titles

# %%
# Get the amount of unique directors
unique_directors = final_df['Director'].unique()
set(unique_directors)
print(unique_directors)
print(f"Number of unique titles: {len(unique_directors)}")
# Out:
# ['Frank Darabont' 'Francis Ford Coppola' 'Christopher Nolan'
#  'Sidney Lumet' 'Peter Jackson' 'Quentin Tarantino' 'Steven Spielberg'
#  'David Fincher' 'Robert Zemeckis' 'Sergio Leone' 'Lana Wachowski'
#  'Martin Scorsese' 'Irvin Kershner' 'Milos Forman' 'Bong Joon Ho'
#  'Fernando Meirelles' 'Hayao Miyazaki' 'Roberto Benigni' 'Jonathan Demme'
#  'George Lucas' 'Akira Kurosawa' 'Todd Phillips' 'Damien Chazelle'
#  'Olivier Nakache' 'Roman Polanski' 'Ridley Scott' 'Tony Kaye'
#  'Bryan Singer' 'Luc Besson' 'Roger Allers' 'James Cameron'
#  'Giuseppe Tornatore' 'Alfred Hitchcock' 'Michael Curtiz'
#  'Charles Chaplin' 'Nadine Labaki' 'Makoto Shinkai' 'Bob Persichetti'
#  'Anthony Russo' 'Lee Unkrich' 'Rajkumar Hirani' 'Andrew Stanton'
#  'Florian Henckel von Donnersmarck' 'Chan-wook Park' 'Stanley Kubrick'
#  'Sam Mendes' 'Thomas Vinterberg' 'Asghar Farhadi' 'Denis Villeneuve'
#  'Michel Gondry' 'Jean-Pierre Jeunet' 'Guy Ritchie' 'Darren Aronofsky'
#  'Gus Van Sant' 'Majid Majidi' 'John Lasseter' 'Mel Gibson'
#  'Brian De Palma' 'Richard Marquand' 'Wolfgang Petersen' 'George Roy Hill'
#  'David Lean' 'Billy Wilder' 'Stanley Donen' 'Orson Welles'
#  'Peter Farrelly' 'Martin McDonagh' 'Juan José Campanella'
#  "Gavin O'Connor" 'Pete Docter' 'Shimit Amin' 'Paul Thomas Anderson'
#  'Guillermo del Toro' 'James McTeigue' 'Oliver Hirschbiegel' 'Ron Howard'
#  'Curtis Hanson' 'Michael Mann' 'Clint Eastwood' 'John McTiernan'
#  'Terry Gilliam' 'John Sturges' 'Joseph L. Mankiewicz' 'John Huston'
#  'Céline Sciamma' 'Xavier Dolan' 'James Mangold' 'Lenny Abrahamson'
#  'Damián Szifron' 'Wes Anderson' 'Steve McQueen' 'Tom McCarthy'
#  'Tomm Moore' 'George Miller' 'David Yates' 'Yôjirô Takita' 'Dean DeBlois'
#  'Sean Penn' 'Ethan Coen' 'Terry George' 'Je-kyu Kang' 'Richard Linklater'
#  'Alejandro G. Iñárritu' 'Ashutosh Gowariker' 'M. Night Shyamalan'
#  'Peter Weir' 'Emir Kusturica' 'Joel Coen' 'Kar-Wai Wong' 'Danny Boyle'
#  'Krzysztof Kieslowski' 'Jim Sheridan' 'Rob Reiner' 'Oliver Stone'
#  'Wim Wenders' 'John Carpenter' 'Alan Parker' 'Ingmar Bergman'
#  'Terry Jones' 'Michael Cimino' 'John G. Avildsen' 'Peter Bogdanovich'
#  'Stuart Rosenberg' 'Robert Aldrich' 'William Wyler' 'Elia Kazan'
#  'Carol Reed' 'Frank Capra' 'Victor Fleming' 'Garth Davis' 'Byron Howard'
#  'Isao Takahata' 'Stephen Chbosky' 'Zoya Akhtar' 'Destin Daniel Cretton'
#  'Gareth Evans' 'Morten Tyldum' 'James Gunn' 'Spike Jonze' 'Tom Hooper'
#  'Tate Taylor' 'Tim Miller' 'Karan Johar' 'José Padilha' 'Joss Whedon'
#  'Vincent Paronnaud' 'Jean-Marc Vallée' 'Gabriele Muccino' 'Edward Zwick'
#  'Paul Greengrass' 'Ki-duk Kim' 'Frank Miller' 'Julian Schnabel'
#  'Brad Bird' 'Martin Campbell' 'Alejandro Amenábar' 'Nikkhil Advani'
#  'Andrew Lau' 'Gore Verbinski' 'Tim Burton' 'Lars von Trier'
#  'Richard Kelly' 'David Lynch' 'Walter Salles' 'Billy Bob Thornton'
#  'Mike Leigh' 'Mamoru Oshii' 'Henry Selick' 'Harold Ramis'
#  'Taylor Hackford' 'Martin Brest' 'Ron Clements' 'Gary Trousdale'
#  'Kevin Costner' 'Spike Lee' 'Barry Levinson' 'Louis Malle'
#  'Richard Attenborough' 'Hal Ashby' 'Woody Allen' 'Mel Brooks'
#  'Franklin J. Schaffner' 'William Friedkin' 'Norman Jewison'
#  'Bernardo Bertolucci' 'Mike Nichols' 'Robert Wise' 'Robert Rossen'
#  'Federico Fellini' 'Howard Hawks' 'Richard Brooks' 'John Ford'
#  'Lewis Milestone' 'Rian Johnson' 'Hirokazu Koreeda' 'Noah Baumbach'
#  'Luca Guadagnino' 'Ken Loach' 'Taika Waititi' 'Matt Ross' 'John Carney'
#  'Dan Gilroy' 'J.J. Abrams' 'Michel Hazanavicius' 'Doug Liman'
#  'Michael Haneke' 'Jacques Audiard' 'Duncan Jones' 'Tomas Alfredson'
#  'Neill Blomkamp' 'Tarsem Singh' 'Ang Lee' 'Christophe Barratier'
#  'Jon Favreau' 'Edgar Wright' 'Alfonso Cuarón' 'Yimou Zhang'
#  'Pedro Almodóvar' 'Danis Tanovic' "Shin'ichirô Watanabe"
#  'Fabián Bielinsky' 'Cameron Crowe' 'Lee Tamahori' 'Tony Scott'
#  'Bob Clark' 'John Landis' 'Bob Fosse' 'George A. Romero' 'Alan J. Pakula'
#  'Alejandro Jodorowsky' 'Luis Buñuel' 'Sam Peckinpah' 'Fred Zinnemann'
#  'Merian C. Cooper' 'Theodore Melfi' 'Paul King' 'Travis Knight'
#  'Kenneth Lonergan' 'Martin Zandvliet' 'Gareth Edwards' 'Greta Gerwig'
#  'Dorota Kobiela' 'Ritesh Batra' 'Don Hall' 'Richard Curtis' 'Josh Cooley'
#  'Adam McKay' 'F. Gary Gray' 'Niels Arden Oplev' 'David O. Russell'
#  'Pierre Morel' 'Mark Herman' 'Joe Wright' 'Nicolas Winding Refn'
#  'Jaco Van Dormael' 'Jonathan Dayton' 'Yash Chopra' 'Anders Thomas Jensen'
#  'Roger Donaldson' 'Satoshi Kon' 'Nick Cassavetes' 'Lukas Moodysson'
#  'Sylvain Chomet' 'Kevin Reynolds' 'Boaz Yakin' 'Troy Duffy'
#  'Joe Johnston' 'Andrew Adamson' 'Andrew Niccol' 'Lasse Hallström'
#  'George P. Cosmatos' 'David Mickey Evans' 'James Ivory' 'Andrew Davis'
#  'Robert De Niro' 'Jim Jarmusch' 'John Singleton' 'Penny Marshall'
#  'Sam Raimi' 'John Hughes' 'Richard Donner' 'Roland Joffé' 'Ivan Reitman'
#  'Philip Kaufman' 'Robert Benton' 'René Laloux' 'Mel Stuart'
#  'John Schlesinger' 'George Cukor' 'Robert Stevenson' 'Ken Annakin'
#  'Jack Clayton' 'David Leitch' 'Taylor Sheridan' 'Jordan Peele'
#  'Christopher McQuarrie' 'Hannes Holm' 'Jemaine Clement' 'James Simone'
#  'James Marsh' 'Matthew Vaughn' 'Josh Boone' 'Alfonso Gomez-Rejon'
#  'Abdellatif Kechiche' 'Abhishek Kapoor' 'Alexander Payne' 'Rich Moore'
#  'Mark Osborne' 'Christopher Miller' 'Ben Affleck' 'Marc Webb'
#  'Alex Garland' 'Susanne Bier' 'Kevin Macdonald' 'Paul McGuigan'
#  'Christian Carion' 'Anton Corbijn' 'Nathan Greno' 'Paul Verhoeven'
#  'Paul Haggis' 'Stephen Chow' 'Brad Anderson' 'Sofia Coppola'
#  'Mike Newell' 'Peter Mullan' 'Wolfgang Becker' 'Jessie Nelson'
#  'Stephen Daldry' 'John Cameron Mitchell' 'Steven Soderbergh'
#  'Yoshiaki Kawajiri' 'Trey Parker' 'Mike Judge' 'Antoine Fuqua'
#  'James L. Brooks' 'Francis Veber' 'Scott Hicks' 'Gregory Hoblit'
#  'Michael Radford' 'Kevin Smith' 'Robert Altman' 'Brian Henson'
#  'James Foley' 'Jon Avnet' 'Bruce Robinson' 'Jean-Jacques Annaud'
#  'Nicholas Meyer' 'Ted Kotcheff' 'Robert Redford' 'Jim Abrahams'
#  'Robert Clouse' 'John Boorman' 'Don Siegel' 'Gene Saks' 'Guy Hamilton'
#  'James Algar' 'Aneesh Chaganty' 'Andrey Zvyagintsev' 'Sean Baker'
#  'Tyler Nilson' 'Deniz Gamze Ergüven' 'Joseph Kosinski' 'Ryan Coogler'
#  'David Mackenzie' 'Stephen Frears' 'Matt Reeves' 'David Ayer'
#  'Hiromasa Yonebayashi' 'Bradley Cooper' 'Pierre Coffin' 'Jonathan Levine'
#  'Bennett Miller' 'Ruben Fleischer' 'John Lee Hancock' 'David Cronenberg'
#  'Olivier Dahan' 'Ronny Yu' 'Neil Burger' 'Zack Snyder' 'James Wan'
#  'Charlie Kaufman' 'Gregg Araki' 'Yann Samuell' 'Marc Forster'
#  'Eric Bress' 'Chris Columbus' 'Ted Demme' 'Mary Harron' 'Tom Tykwer'
#  'Terrence Malick' 'Tony Bancroft' 'Alex Proyas' 'Joel Schumacher'
#  'Jonathan Lynn' 'Marc Caro' 'David Zucker' 'Mark Rydell' 'Walter Hill'
#  'James Frawley' 'Brian G. Hutton' 'Wolfgang Reitherman' 'Richard Lester']
# Number of unique titles: 402

# %% [markdown]
# There are 402 unique directors

# %% [markdown]
# #### Missing Data

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 997
# Data columns (total 34 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   714 non-null    object
#  1   Released_Year  714 non-null    int64
#  2   Certificate    714 non-null    object
#  3   Runtime        714 non-null    float64
#  4   IMDB_Rating    714 non-null    float64
#  5   Meta_score     714 non-null    float64
#  6   Director       714 non-null    object
#  7   Star1          714 non-null    object
#  8   Star2          714 non-null    object
#  9   Star3          714 non-null    object
#  10  Star4          714 non-null    object
#  11  No_of_Votes    714 non-null    int64
#  12  Gross          714 non-null    float64
#  13  Action         714 non-null    int64
#  14  Adventure      714 non-null    int64
#  15  Animation      714 non-null    int64
#  16  Biography      714 non-null    int64
#  17  Comedy         714 non-null    int64
#  18  Crime          714 non-null    int64
#  19  Drama          714 non-null    int64
#  20  Family         714 non-null    int64
#  21  Fantasy        714 non-null    int64
#  22  Film-Noir      714 non-null    int64
#  23  History        714 non-null    int64
#  24  Horror         714 non-null    int64
#  25  Music          714 non-null    int64
#  26  Musical        714 non-null    int64
#  27  Mystery        714 non-null    int64
#  28  Romance        714 non-null    int64
#  29  Sci-Fi         714 non-null    int64
#  30  Sport          714 non-null    int64
#  31  Thriller       714 non-null    int64
#  32  War            714 non-null    int64
#  33  Western        714 non-null    int64
# dtypes: float64(4), int64(23), object(7)
# memory usage: 195.2+ KB

# %% [markdown]
# Since there are 714 entreis and every column has 714 non-null entries, there is zero missing data in any column

# %% [markdown]
# #### Distribution of Continuous Variables

# %%
# Get statistical summary for numerical columns
final_df.describe()
# Out:
#        Released_Year     Runtime  IMDB_Rating  Meta_score   No_of_Votes  \
# count     714.000000  714.000000   714.000000  714.000000  7.140000e+02
# mean     1995.735294  123.715686     7.937115   77.158263  3.561348e+05
# std        18.585196   25.887535     0.293278   12.401144  3.539011e+05
# min      1930.000000   72.000000     7.600000   28.000000  2.522900e+04
# 25%      1987.000000  104.250000     7.700000   70.000000  9.600975e+04
# 50%      2001.000000  120.000000     7.900000   78.000000  2.366025e+05
# 75%      2009.750000  136.000000     8.100000   86.000000  5.077922e+05
# max      2019.000000  238.000000     9.300000  100.000000  2.343110e+06
#
#               Gross      Action   Adventure   Animation   Biography  ...  \
# count  7.140000e+02  714.000000  714.000000  714.000000  714.000000  ...
# mean   7.851359e+07    0.196078    0.228291    0.088235    0.123249  ...
# std    1.149780e+08    0.397307    0.420026    0.283836    0.328954  ...
# min    1.305000e+03    0.000000    0.000000    0.000000    0.000000  ...
# 25%    6.157408e+06    0.000000    0.000000    0.000000    0.000000  ...
# 50%    3.485015e+07    0.000000    0.000000    0.000000    0.000000  ...
# 75%    1.024641e+08    0.000000    0.000000    0.000000    0.000000  ...
# max    9.366622e+08    1.000000    1.000000    1.000000    1.000000  ...
#
#            Horror       Music     Musical     Mystery     Romance      Sci-Fi  \
# count  714.000000  714.000000  714.000000  714.000000  714.000000  714.000000
# mean     0.025210    0.037815    0.015406    0.098039    0.123249    0.078431
# std      0.156873    0.190883    0.123248    0.297576    0.328954    0.269038
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#             Sport    Thriller         War     Western
# count  714.000000  714.000000  714.000000  714.000000
# mean     0.023810    0.138655    0.040616    0.022409
# std      0.152562    0.345829    0.197538    0.148113
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# This is a summary  of the numerical columns. This table gives insight on how the numerical data is distributed among the films. Each column requires a unique understanding but an example is looking at the mean of the Runtime variable, we can conclude that most movies have a runtime that is close to 124 minutes. However, this data has a standard deviation of 26 so the data must be fairly spread out

# %% [markdown]
# #### Outliers

# %%
# Define the variables are interested in finding outliers for
vars = ['Runtime', 'IMDB_Rating', 'Meta_score', 'No_of_Votes', 'Gross']


def outlier(column):
    # Calculate IQR and bounds
    Q1 = final_df[column].quantile(0.25)
    Q3 = final_df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identifying outliers
    outliers = final_df[(final_df[column] < lower_bound) | (final_df[column] > upper_bound)]

    print(f"Outliers for {column}: {outliers.shape[0]}")

# Loop through for the variables we are interested in
for column in vars:
    outlier(column)
# Out:
# Outliers for Runtime: 22
# Outliers for IMDB_Rating: 13
# Outliers for Meta_score: 10
# Outliers for No_of_Votes: 31
# Outliers for Gross: 60

# %% [markdown]
# As the above print statements indicate, there are a couple outliers for the five continuous variables we are interested in investigating.

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# | Column Name         | Data Type | Description                                                                                          |
# |---------------------|-----------|------------------------------------------------------------------------------------------------------|
# | Series_Title        | object    | The title of the movie                                                                               |
# | Released_Year       | int64     | The year the movie was released                                                                      |
# | Certificate         | object    | The certification of the movie                                                                       |
# | Runtime             | float64   | The runtime of the movie in minutes                                                                  |
# | [All Genre Columns] | int64     | A genre the movie may fall under (A 0 indicates the movie does not fall under this genre, a 1 means it does) |
# | IMDB_Rating         | float64   | The IMDB rating of the movie                                                                         |
# | Meta_score          | float64   | The Metacritic score of the movie                                                                    |
# | Director            | object    | The director of the movie                                                                            |
# | Star1               | object    | The primary star of the movie                                                                        |
# | Star2               | object    | The secondary star of the movie                                                                      |
# | Star3               | object    | Additional star of the movie                                                                         |
# | Star4               | object    | Additional star of the movie                                                                         |
# | No_of_Votes         | int64     | The number of IMDB votes for the movie                                                               |
# | Gross               | float64   | The gross earnings of the movie in the US market, in dollars                                         |

# %% [markdown]
# ### Potential UI Components

# %% [markdown]
# 1. Interactive data charts and graphs that allow user to select individual data points and view a summary of that data point
# 2. Dropdown filters for categorial columns for user to see movies with given specifications
# 3. Slider filters for numerical columns for user to see movies with given specifications
# 4. Radio buttons for users to select what type of visulization they want

# %% [markdown]
# ### Potential Data Visualizations

# %% [markdown]
# 1. Amount of movies over time in a line chart or bar chart. This would show how the number of movies has changed over the years to identify trends in movie production. Can highlight significant periods in film history. Hover for exact counts, click on a year to see a list of movies released that year.
# 2. Top directors by average rating in a horizontal bar chart. Rank directors based on the average rating of their movies. Hovering will show average rating and some movies that are directed by them.
# 3. Actors genre preferance in a stacked bar chart or radar chart. For selected actors, display the distribution of their movie genres. Hovering will show exact counts or percentages of movies an actor has in each genre. Click on actor in dropdown to filter.
# 4. Genre popularity over time in a stacked area chart or multi-line chart. Display the popularity of different genres over time by plotting the number of movies in each genre by year. Click on a genre in dropdown or line to filter the dashboard to show only movies from that genre
# 5. Ratings versus Gross in a scatter plot. Plot each movie with its rating on one axis and its gross earnings on the other. Hover to display the movie title, director, and year.
